# %% [markdown]
# ### 부스팅 기법
# </br>ada boost: 여러 알고리즘에 대해서 예측율이 떨어진 부분에 가중치를 부여를 해서 전체 알고리즘의 결과값을 합치는 방식의 기법
# </br>gradient boosting: 모델 예측치에 대한 잔차에 대해서 반복적으로 분류기에 넣어서 오류를 줄이는 방식의 기법
# <br>XGboost: gbm 방식 + 오차에 대한 정규화를 통해서 과적합 확률을 줄인 방식의 기법-> 이것은 sklearn에서 제공되지 않는다.

# %% [markdown]
# sklearn.ensemble.GradientBoostingClassifier
# ●class sklearn.ensemble.GradientBoostingClassifier(*, loss='deviance', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time 
import warnings
warnings.filterwarnings('ignore')
import dsetmod as d


X_train, X_test, y_train, y_test = d.get_human_dataset()

start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(X_train,y_train)
gb_pred = gb_clf.predict(X_test)
gb_accuracy = accuracy_score(y_test,gb_pred)

print(gb_accuracy)
print(time.time()-start_time())
# Out:
# 0.9389209365456397
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [65], in <module>
#      15 gb_accuracy = accuracy_score(y_test,gb_pred)
#      17 print(gb_accuracy)
# ---> 18 print(time.time()-start_time())
#
# TypeError: 'float' object is not callable

# %% [markdown]
# _class_ xgboost.XGBRegressor(_*_,  _objective='reg:squarederror'_,  _**kwargs_)[](https://xgboost.readthedocs.io/en/stable/python/python_api.html#xgboost.XGBRegressor "Permalink to this definition")
#
# Bases:  `xgboost.sklearn.XGBModel`,  [`object`](https://docs.python.org/3.6/library/functions.html#object "(in Python v3.6)")
#
# Implementation of the scikit-learn API for XGBoost regression.
#
# Parameters
#
# -   **n_estimators**  ([_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")) – Number of gradient boosted trees. Equivalent to number of boosting rounds.
#
# -   **max_depth**  (_Optional__[_[_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]_) – Maximum tree depth for base learners.
#
# -   **learning_rate**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Boosting learning rate (xgb’s “eta”)
#
# -   **verbosity**  (_Optional__[_[_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]_) – The degree of verbosity. Valid values are 0 (silent) - 3 (debug).
#
# -   **objective**  ([_Union_](https://docs.python.org/3.6/library/typing.html#typing.Union "(in Python v3.6)")_[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_,_ [_Callable_](https://docs.python.org/3.6/library/typing.html#typing.Callable "(in Python v3.6)")_[__[_[_numpy.ndarray_](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html#numpy.ndarray "(in NumPy v1.22)")_,_ [_numpy.ndarray_](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html#numpy.ndarray "(in NumPy v1.22)")_]__,_ [_Tuple_](https://docs.python.org/3.6/library/typing.html#typing.Tuple "(in Python v3.6)")_[_[_numpy.ndarray_](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html#numpy.ndarray "(in NumPy v1.22)")_,_ [_numpy.ndarray_](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html#numpy.ndarray "(in NumPy v1.22)")_]__]__,_ _NoneType__]_) – Specify the learning task and the corresponding learning objective or a custom objective function to be used (see note below).
#
# -   **booster**  (_Optional__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_]_) – Specify which booster to use: gbtree, gblinear or dart.
#
# -   **tree_method**  (_Optional__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_]_) – Specify which tree method to use. Default to auto. If this parameter is set to default, XGBoost will choose the most conservative option available. It’s recommended to study this option from the parameters document:  [https://xgboost.readthedocs.io/en/latest/treemethod.html](https://xgboost.readthedocs.io/en/latest/treemethod.html).
#
# -   **n_jobs**  (_Optional__[_[_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]_) – Number of parallel threads used to run xgboost. When used with other Scikit-Learn algorithms like grid search, you may choose which algorithm to parallelize and balance the threads. Creating thread contention will significantly slow down both algorithms.
#
# -   **gamma**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Minimum loss reduction required to make a further partition on a leaf node of the tree.
#
# -   **min_child_weight**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Minimum sum of instance weight(hessian) needed in a child.
#
# -   **max_delta_step**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Maximum delta step we allow each tree’s weight estimation to be.
#
# -   **subsample**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Subsample ratio of the training instance.
#
# -   **colsample_bytree**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Subsample ratio of columns when constructing each tree.
#
# -   **colsample_bylevel**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Subsample ratio of columns for each level.
#
# -   **colsample_bynode**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Subsample ratio of columns for each split.
#
# -   **reg_alpha**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – L1 regularization term on weights (xgb’s alpha).
#
# -   **reg_lambda**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – L2 regularization term on weights (xgb’s lambda).
#
# -   **scale_pos_weight**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – Balancing of positive and negative weights.
#
# -   **base_score**  (_Optional__[_[_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_]_) – The initial prediction score of all instances, global bias.
#
# -   **random_state**  (_Optional__[__Union__[_[_numpy.random.RandomState_](https://numpy.org/doc/stable/reference/random/legacy.html#numpy.random.RandomState "(in NumPy v1.22)")_,_ [_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]__]_) –
#
#     Random number seed.
#
#     Note
#
#     Using gblinear booster with shotgun updater is nondeterministic as it uses Hogwild algorithm.
#
# -   **missing**  ([_float_](https://docs.python.org/3.6/library/functions.html#float "(in Python v3.6)")_,_ _default np.nan_) – Value in the data which needs to be present as a missing value.
#
# -   **num_parallel_tree**  (_Optional__[_[_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]_) – Used for boosting random forest.
#
# -   **monotone_constraints**  (_Optional__[__Union__[__Dict__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_,_ [_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]__,_ [_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_]__]_) – Constraint of variable monotonicity. See tutorial for more information.
#
# -   **interaction_constraints**  (_Optional__[__Union__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_,_ _List__[__Tuple__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_]__]__]__]_) – Constraints for interaction representing permitted interactions. The constraints must be specified in the form of a nest list, e.g. [[0, 1], [2, 3, 4]], where each inner list is a group of indices of features that are allowed to interact with each other. See tutorial for more information
#
# -   **importance_type**  (_Optional__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_]_) –
#
#     The feature importance type for the feature_importances_ property:
#
#     -   For tree model, it’s either “gain”, “weight”, “cover”, “total_gain” or “total_cover”.
#
#     -   For linear model, only “weight” is defined and it’s the normalized coefficients without bias.
#
#
# -   **gpu_id**  (_Optional__[_[_int_](https://docs.python.org/3.6/library/functions.html#int "(in Python v3.6)")_]_) – Device ordinal.
#
# -   **validate_parameters**  (_Optional__[_[_bool_](https://docs.python.org/3.6/library/functions.html#bool "(in Python v3.6)")_]_) – Give warnings for unknown parameter.
#
# -   **predictor**  (_Optional__[_[_str_](https://docs.python.org/3.6/library/stdtypes.html#str "(in Python v3.6)")_]_) – Force XGBoost to use specific predictor, available choices are [cpu_predictor, gpu_predictor].
#
# -   **enable_categorical**  ([_bool_](https://docs.python.org/3.6/library/functions.html#bool "(in Python v3.6)")) –
#
#     New in version 1.5.0.
#
#     Experimental support for categorical data. Do not set to true unless you are interested in development. Only valid when  gpu_hist  and dataframe are used.
#
# -   **kwargs**  ([_dict_](https://docs.python.org/3.6/library/stdtypes.html#dict "(in Python v3.6)")_,_ _optional_) –
#
#     Keyword arguments for XGBoost Booster object. Full documentation of parameters can be found here:  [https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst](https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst). Attempting to set a parameter via the constructor args and **kwargs dict simultaneously will result in a TypeError.
#
#     Note
#
#     **kwargs unsupported by scikit-learn
#
#     **kwargs is unsupported by scikit-learn. We do not guarantee that parameters passed via this argument will interact properly with scikit-learn.
#
#     Note
#
#     Custom objective function
#
#     A custom objective function can be provided for the  `objective`  parameter. In this case, it should have the signature  `objective(y_true,  y_pred)  ->  grad,  hess`:
#
#     y_true: array_like of shape [n_samples]
#
#     The target values
#
#     y_pred: array_like of shape [n_samples]
#
#     The predicted values
#
#     grad: array_like of shape [n_samples]
#
#     The value of the gradient for each sample point.
#
#     hess: array_like of shape [n_samples]
#
#     The value of the second derivative for each sample point

# %%
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score , recall_score
from sklearn.metrics import f1_score, roc_auc_score
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()
X_features = dataset.data
y_labels = dataset.target

cancer_df = pd.DataFrame(data=X_features, columns=dataset.feature_names)
cancer_df['target'] = y_labels

cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features,y_labels,test_size=0.3,random_state=126)

xgb_clf = XGBClassifier(n_estimators=400, learning_rate=0.1,max_depth=3)
xgb_clf.fit(X_train,y_train)

pred = xgb_clf.predict(X_test)
pred_proba = xgb_clf.predict_proba(X_test)
# Out:
# [13:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

def get_clf_eval(y_test,pred):
    confusion = confusion_matrix(y_test,pred)
    accuracy = accuracy_score(y_test,pred)
    precision = precision_score(y_test,pred)
    recall = recall_score(y_test,pred)
    F1 = f1_score(y_test,pred)
    AUC = roc_auc_score(y_test,pred)
    lr_probs = pred_proba[:,1]
    
    ns_probs = [0 for _ in range(len(y_test))]
    ns_fpr, ns_tpr,_ = roc_curve(y_test, ns_probs)
    lr_fpr, lr_tpr,_ = roc_curve(y_test, lr_probs)
    
    plt.plot(ns_fpr,ns_tpr,linestyle='--',label='No Skill')
    plt.plot(lr_fpr,lr_tpr,marker='.', label='XGBOOST')
    
    plt.xlabel("False Postive Rate")
    plt.ylabel('True Positive Rate')
    
    plt.legend()
    plt.show()
    
    print(f'오차행렬\n {confusion}')
    print(f'정확도\n {accuracy}')
    print(f'재현율\n {recall}')
    print(f'f1_score\n {f1_score}')
    print(f'AUC\n {AUC}')
    
get_clf_eval(y_test,pred)
# Out:
# 오차행렬
#  [[ 58   4]
#  [  1 108]]
# 정확도
#  0.9707602339181286
# 재현율
#  0.9908256880733946
# f1_score
#  <function f1_score at 0x000001E18B5C7D90>
# AUC
#  0.9631547795205683

# %%
fig, ax = plt.subplots(figsize=(10,12))

plot_importance(xgb_clf, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb_clf = XGBClassifier(n_estimators=400, learning_rate=0.1,max_depth=3)

xgb_clf.fit(X_train,y_train, early_stopping_rounds=100, eval_metric='logloss', eval_set=[(X_test,y_test)],verbose=True)

pred = xgb_clf.predict(X_test)
pred_proba = xgb_clf.predict_proba(X_test)

ns_probs = [0 for _ in range(len(y_test))]
ns_fpr, ns_tpr,_ = roc_curve(y_test, ns_probs)
# Out:
# [0]	validation_0-logloss:0.61478
# [1]	validation_0-logloss:0.54958
# [2]	validation_0-logloss:0.49824
# [3]	validation_0-logloss:0.45383
# [4]	validation_0-logloss:0.41471
# [5]	validation_0-logloss:0.38285
# [6]	validation_0-logloss:0.35442
# [7]	validation_0-logloss:0.33043
# [8]	validation_0-logloss:0.30884
# [9]	validation_0-logloss:0.28752
# [10]	validation_0-logloss:0.26886
# [11]	validation_0-logloss:0.25489
# [12]	validation_0-logloss:0.23888
# [13]	validation_0-logloss:0.22526
# [14]	validation_0-logloss:0.21423
# [15]	validation_0-logloss:0.20274
# [16]	validation_0-logloss:0.19406
# [17]	validation_0-logloss:0.18565
# [18]	validation_0-logloss:0.17795
# [19]	validation_0-logloss:0.17006
# [20]	validation_0-logloss:0.16235
# [21]	validation_0-logloss:0.15660
# [22]	validation_0-logloss:0.15023
# [23]	validation_0-logloss:0.14447
# [24]	validation_0-logloss:0.13882
# [25]	validation_0-logloss:0.13479
# [26]	validation_0-logloss:0.13130
# [27]	validation_0-logloss:0.12822
# [28]	validation_0-logloss:0.12393
# [29]	validation_0-logloss:0.12148
# [30]	validation_0-logloss:0.11976
# [31]	validation_0-logloss:0.11891
# [32]	validation_0-logloss:0.11537
# [33]	validation_0-logloss:0.11458
# [34]	validation_0-logloss:0.11437
# [35]	validation_0-logloss:0.11219
# [36]	validation_0-logloss:0.11082
# [37]	validation_0-logloss:0.10974
# [38]	validation_0-logloss:0.10739
# [39]	validation_0-logloss:0.10740
# [40]	validation_0-logloss:0.10719
# [41]	validation_0-logloss:0.10519
# [42]	validation_0-logloss:0.10506
# [43]	validation_0-logloss:0.10544
# [44]	validation_0-logloss:0.10295
# [45]	validation_0-logloss:0.10140
# [46]	validation_0-logloss:0.10066
# [47]	validation_0-logloss:0.10010
# [48]	validation_0-logloss:0.10062
# [49]	validation_0-logloss:0.09952
# [50]	validation_0-logloss:0.10042
# [51]	validation_0-logloss:0.10085
# [52]	validation_0-logloss:0.09988
# [53]	validation_0-logloss:0.10058
# [54]	validation_0-logloss:0.10112
# [55]	validation_0-logloss:0.10197
# [56]	validation_0-logloss:0.10007
# [57]	validation_0-logloss:0.10031
# [58]	validation_0-logloss:0.09981
# [59]	validation_0-logloss:0.10007
# [60]	validation_0-logloss:0.09835
# [61]	validation_0-logloss:0.09821
# [62]	validation_0-logloss:0.09853
# [63]	validation_0-logloss:0.09772
# [64]	validation_0-logloss:0.09736
# [65]	validation_0-logloss:0.09681
# [66]	validation_0-logloss:0.09633
# [67]	validation_0-logloss:0.09718
# [68]	validation_0-logloss:0.09750
# [69]	validation_0-logloss:0.09650
# [70]	validation_0-logloss:0.09648
# [71]	validation_0-logloss:0.09583
# [72]	validation_0-logloss:0.09565
# [73]	validation_0-logloss:0.09474
# [74]	validation_0-logloss:0.09470
# [75]	validation_0-logloss:0.09419
# [76]	validation_0-logloss:0.09484
# [77]	validation_0-logloss:0.09482
# [78]	validation_0-logloss:0.09425
# [79]	validation_0-logloss:0.09471
# [80]	validation_0-logloss:0.09420
# [81]	validation_0-logloss:0.09404
# [82]	validation_0-logloss:0.09318
# [83]	validation_0-logloss:0.09273
# [84]	validation_0-logloss:0.09284
# [85]	validation_0-logloss:0.09268
# [86]	validation_0-logloss:0.09187
# [87]	validation_0-logloss:0.09207
# [88]	validation_0-logloss:0.09197
# [89]	validation_0-logloss:0.09164
# [90]	validation_0-logloss:0.09123
# [91]	validation_0-logloss:0.09158
# [92]	validation_0-logloss:0.09090
# [93]	validation_0-logloss:0.09055
# [94]	validation_0-logloss:0.09026
# [95]	validation_0-logloss:0.09009
# [96]	validation_0-logloss:0.08972
# [97]	validation_0-logloss:0.09004
# [98]	validation_0-logloss:0.08932
# [99]	validation_0-logloss:0.08978
# [100]	validation_0-logloss:0.08881
# [101]	validation_0-logloss:0.08916
# [102]	validation_0-logloss:0.08927
# [103]	validation_0-logloss:0.08899
# [104]	validation_0-logloss:0.08884
# [105]	validation_0-logloss:0.08864
# [106]	validation_0-logloss:0.08899
# [107]	validation_0-logloss:0.08931
# [108]	validation_0-logloss:0.08904
# [109]	validation_0-logloss:0.08885
# [110]	validation_0-logloss:0.08922
# [111]	validation_0-logloss:0.08934
# [112]	validation_0-logloss:0.08909
# [113]	validation_0-logloss:0.08888
# [114]	validation_0-logloss:0.08920
# [115]	validation_0-logloss:0.08919
# [116]	validation_0-logloss:0.08905
# [117]	validation_0-logloss:0.08865
# [118]	validation_0-logloss:0.08780
# [119]	validation_0-logloss:0.08813
# [120]	validation_0-logloss:0.08800
# [121]	validation_0-logloss:0.08849
# [122]	validation_0-logloss:0.08861
# [123]	validation_0-logloss:0.08835
# [124]	validation_0-logloss:0.08815
# [125]	validation_0-logloss:0.08793
# [126]	validation_0-logloss:0.08775
# [127]	validation_0-logloss:0.08806
# [128]	validation_0-logloss:0.08823
# [129]	validation_0-logloss:0.08812
# [130]	validation_0-logloss:0.08748
# [131]	validation_0-logloss:0.08763
# [132]	validation_0-logloss:0.08703
# [133]	validation_0-logloss:0.08739
# [134]	validation_0-logloss:0.08682
# [135]	validation_0-logloss:0.08624
# [136]	validation_0-logloss:0.08641
# [137]	validation_0-logloss:0.08578
# [138]	validation_0-logloss:0.08568
# [139]	validation_0-logloss:0.08586
# [140]	validation_0-logloss:0.08580
# [141]	validation_0-logloss:0.08560
# [142]	validation_0-logloss:0.08548
# [143]	validation_0-logloss:0.08565
# [144]	validation_0-logloss:0.08546
# [145]	validation_0-logloss:0.08531
# [146]	validation_0-logloss:0.08512
# [147]	validation_0-logloss:0.08472
# [148]	validation_0-logloss:0.08502
# [149]	validation_0-logloss:0.08459
# [150]	validation_0-logloss:0.08455
# [151]	validation_0-logloss:0.08485
# [152]	validation_0-logloss:0.08468
# [153]	validation_0-logloss:0.08456
# [154]	validation_0-logloss:0.08467
# [155]	validation_0-logloss:0.08478
# [156]	validation_0-logloss:0.08444
# [157]	validation_0-logloss:0.08404
# [158]	validation_0-logloss:0.08415
# [159]	validation_0-logloss:0.08377
# [160]	validation_0-logloss:0.08396
# [161]	validation_0-logloss:0.08407
# [162]	validation_0-logloss:0.08383
# [163]	validation_0-logloss:0.08374
# [164]	validation_0-logloss:0.08385
# [165]	validation_0-logloss:0.08382
# [166]	validation_0-logloss:0.08372
# [167]	validation_0-logloss:0.08401
# [168]	validation_0-logloss:0.08398
# [169]	validation_0-logloss:0.08389
# [170]	validation_0-logloss:0.08399
# [171]	validation_0-logloss:0.08418
# [172]	validation_0-logloss:0.08431
# [173]	validation_0-logloss:0.08395
# [174]	validation_0-logloss:0.08413
# [175]	validation_0-logloss:0.08410
# [176]	validation_0-logloss:0.08423
# [177]	validation_0-logloss:0.08433
# [178]	validation_0-logloss:0.08398
# [179]	validation_0-logloss:0.08411
# [180]	validation_0-logloss:0.08438
# [181]	validation_0-logloss:0.08403
# [182]	validation_0-logloss:0.08427
# [183]	validation_0-logloss:0.08418
# [184]	validation_0-logloss:0.08416
# [185]	validation_0-logloss:0.08407
# [186]	validation_0-logloss:0.08420
# [187]	validation_0-logloss:0.08446
# [188]	validation_0-logloss:0.08412
# [189]	validation_0-logloss:0.08435
# [190]	validation_0-logloss:0.08434
# [191]	validation_0-logloss:0.08424
# [192]	validation_0-logloss:0.08435
# [193]	validation_0-logloss:0.08452
# [194]	validation_0-logloss:0.08465
# [195]	validation_0-logloss:0.08475
# [196]	validation_0-logloss:0.08473
# [197]	validation_0-logloss:0.08490
# [198]	validation_0-logloss:0.08502
# [199]	validation_0-logloss:0.08511
# [200]	validation_0-logloss:0.08502
# [201]	validation_0-logloss:0.08500
# [202]	validation_0-logloss:0.08491
# [203]	validation_0-logloss:0.08513
# [204]	validation_0-logloss:0.08529
# [205]	validation_0-logloss:0.08538
# [206]	validation_0-logloss:0.08550
# [207]	validation_0-logloss:0.08548
# [208]	validation_0-logloss:0.08538
# [209]	validation_0-logloss:0.08529
# [210]	validation_0-logloss:0.08495
# [211]	validation_0-logloss:0.08515
# [212]	validation_0-logloss:0.08502
# [213]	validation_0-logloss:0.08511
# [214]	validation_0-logloss:0.08527
# [215]	validation_0-logloss:0.08517
# [216]	validation_0-logloss:0.08526
# [217]	validation_0-logloss:0.08538
# [218]	validation_0-logloss:0.08549
# [219]	validation_0-logloss:0.08547
# [220]	validation_0-logloss:0.08556
# [221]	validation_0-logloss:0.08568
# [222]	validation_0-logloss:0.08579
# [223]	validation_0-logloss:0.08570
# [224]	validation_0-logloss:0.08591
# [225]	validation_0-logloss:0.08579
# [226]	validation_0-logloss:0.08569
# [227]	validation_0-logloss:0.08579
# [228]	validation_0-logloss:0.08543
# [229]	validation_0-logloss:0.08554
# [230]	validation_0-logloss:0.08546
# [231]	validation_0-logloss:0.08545
# [232]	validation_0-logloss:0.08535
# [233]	validation_0-logloss:0.08555
# [234]	validation_0-logloss:0.08547
# [235]	validation_0-logloss:0.08513
# [236]	validation_0-logloss:0.08501
# [237]	validation_0-logloss:0.08492
# [238]	validation_0-logloss:0.08501
# [239]	validation_0-logloss:0.08511
# [240]	validation_0-logloss:0.08522
# [241]	validation_0-logloss:0.08531
# [242]	validation_0-logloss:0.08530
# [243]	validation_0-logloss:0.08549
# [244]	validation_0-logloss:0.08541
# [245]	validation_0-logloss:0.08539
# [246]	validation_0-logloss:0.08549
# [247]	validation_0-logloss:0.08558
# [248]	validation_0-logloss:0.08549
# [249]	validation_0-logloss:0.08538
# [250]	validation_0-logloss:0.08553
# [251]	validation_0-logloss:0.08564
# [252]	validation_0-logloss:0.08556
# [253]	validation_0-logloss:0.08555
# [254]	validation_0-logloss:0.08546
# [255]	validation_0-logloss:0.08555
# [256]	validation_0-logloss:0.08554
# [257]	validation_0-logloss:0.08523
# [258]	validation_0-logloss:0.08515
# [259]	validation_0-logloss:0.08525
# [260]	validation_0-logloss:0.08522
# [261]	validation_0-logloss:0.08541
# [262]	validation_0-logloss:0.08536
# [263]	validation_0-logloss:0.08535
# [264]	validation_0-logloss:0.08544
# [265]	validation_0-logloss:0.08539
# [266]	validation_0-logloss:0.08508

# %%
xgb_clf = XGBClassifier(n_estimators=400, learning_rate=0.1,max_depth=3)

xgb_clf.fit(X_train,y_train, early_stopping_rounds=200, eval_metric='logloss', eval_set=[(X_test,y_test)],verbose=True)

pred = xgb_clf.predict(X_test)
pred_proba = xgb_clf.predict_proba(X_test)

ns_probs = [0 for _ in range(len(y_test))]
ns_fpr, ns_tpr,_ = roc_curve(y_test, ns_probs)

# %%
#svm 예시
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5)

from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100)
clf.fit(X_train,y_train)
prediction = clf.predict(X_test)
print(X_test)

clf.score(X_test,y_test)
# Out:
# [[6.6 3.  4.4 1.4]
#  [5.1 3.5 1.4 0.2]
#  [6.7 3.1 5.6 2.4]
#  [5.1 3.8 1.5 0.3]
#  [5.  3.5 1.6 0.6]
#  [4.6 3.4 1.4 0.3]
#  [4.7 3.2 1.3 0.2]
#  [5.1 3.8 1.6 0.2]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [6.  2.2 4.  1. ]
#  [6.3 2.3 4.4 1.3]
#  [6.1 3.  4.6 1.4]
#  [5.5 2.4 3.8 1.1]
#  [4.4 3.  1.3 0.2]
#  [7.2 3.2 6.  1.8]
#  [4.9 2.4 3.3 1. ]
#  [5.4 3.9 1.7 0.4]
#  [7.7 3.  6.1 2.3]
#  [5.4 3.4 1.5 0.4]
#  [7.3 2.9 6.3 1.8]
#  [6.  2.9 4.5 1.5]
#  [5.8 2.6 4.  1.2]
#  [5.8 2.7 3.9 1.2]
#  [5.4 3.4 1.7 0.2]
#  [4.9 3.1 1.5 0.1]
#  [7.7 2.8 6.7 2. ]
#  [5.  3.4 1.6 0.4]
#  [6.5 2.8 4.6 1.5]
#  [5.6 2.8 4.9 2. ]
#  [6.8 2.8 4.8 1.4]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.1 4.4 1.4]
#  [6.9 3.1 5.1 2.3]
#  [4.9 3.6 1.4 0.1]
#  [6.7 3.3 5.7 2.1]
#  [5.9 3.  4.2 1.5]
#  [5.7 2.8 4.1 1.3]
#  [5.5 2.4 3.7 1. ]
#  [4.8 3.4 1.9 0.2]
#  [5.1 3.8 1.9 0.4]
#  [7.2 3.6 6.1 2.5]
#  [6.3 3.4 5.6 2.4]
#  [5.5 2.3 4.  1.3]
#  [6.2 2.9 4.3 1.3]
#  [7.1 3.  5.9 2.1]
#  [5.2 4.1 1.5 0.1]
#  [4.8 3.4 1.6 0.2]
#  [6.8 3.  5.5 2.1]
#  [5.  3.6 1.4 0.2]
#  [6.9 3.1 4.9 1.5]
#  [5.  2.3 3.3 1. ]
#  [7.2 3.  5.8 1.6]
#  [6.3 3.3 4.7 1.6]
#  [6.4 2.8 5.6 2.1]
#  [6.9 3.1 5.4 2.1]
#  [6.4 3.1 5.5 1.8]
#  [5.6 3.  4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [6.7 3.3 5.7 2.5]
#  [5.6 2.7 4.2 1.3]
#  [5.2 3.4 1.4 0.2]
#  [5.4 3.9 1.3 0.4]
#  [5.8 2.8 5.1 2.4]
#  [4.8 3.  1.4 0.1]
#  [5.1 3.3 1.7 0.5]
#  [6.1 2.6 5.6 1.4]
#  [5.9 3.  5.1 1.8]
#  [5.9 3.2 4.8 1.8]
#  [4.6 3.2 1.4 0.2]
#  [7.7 3.8 6.7 2.2]
#  [6.4 2.9 4.3 1.3]
#  [6.4 3.2 5.3 2.3]
#  [5.7 2.9 4.2 1.3]
#  [6.4 3.2 4.5 1.5]]
# 0.9866666666666667

# %%
#knn 알고리즘 예시
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.feature_names)
print(iris.target_names)
print(iris.data[0])
print(iris.target[0])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# [5.1 3.5 1.4 0.2]
# 0

# %%
for i in range(len(iris.target)):
    print(f'Example {i}: label {iris.target[i]}, features {iris.data[i]}, name {iris.target_names[iris.target[i]]}')
# Out:
# Example 0: label 0, features [5.1 3.5 1.4 0.2], name setosa
# Example 1: label 0, features [4.9 3.  1.4 0.2], name setosa
# Example 2: label 0, features [4.7 3.2 1.3 0.2], name setosa
# Example 3: label 0, features [4.6 3.1 1.5 0.2], name setosa
# Example 4: label 0, features [5.  3.6 1.4 0.2], name setosa
# Example 5: label 0, features [5.4 3.9 1.7 0.4], name setosa
# Example 6: label 0, features [4.6 3.4 1.4 0.3], name setosa
# Example 7: label 0, features [5.  3.4 1.5 0.2], name setosa
# Example 8: label 0, features [4.4 2.9 1.4 0.2], name setosa
# Example 9: label 0, features [4.9 3.1 1.5 0.1], name setosa
# Example 10: label 0, features [5.4 3.7 1.5 0.2], name setosa
# Example 11: label 0, features [4.8 3.4 1.6 0.2], name setosa
# Example 12: label 0, features [4.8 3.  1.4 0.1], name setosa
# Example 13: label 0, features [4.3 3.  1.1 0.1], name setosa
# Example 14: label 0, features [5.8 4.  1.2 0.2], name setosa
# Example 15: label 0, features [5.7 4.4 1.5 0.4], name setosa
# Example 16: label 0, features [5.4 3.9 1.3 0.4], name setosa
# Example 17: label 0, features [5.1 3.5 1.4 0.3], name setosa
# Example 18: label 0, features [5.7 3.8 1.7 0.3], name setosa
# Example 19: label 0, features [5.1 3.8 1.5 0.3], name setosa
# Example 20: label 0, features [5.4 3.4 1.7 0.2], name setosa
# Example 21: label 0, features [5.1 3.7 1.5 0.4], name setosa
# Example 22: label 0, features [4.6 3.6 1.  0.2], name setosa
# Example 23: label 0, features [5.1 3.3 1.7 0.5], name setosa
# Example 24: label 0, features [4.8 3.4 1.9 0.2], name setosa
# Example 25: label 0, features [5.  3.  1.6 0.2], name setosa
# Example 26: label 0, features [5.  3.4 1.6 0.4], name setosa
# Example 27: label 0, features [5.2 3.5 1.5 0.2], name setosa
# Example 28: label 0, features [5.2 3.4 1.4 0.2], name setosa
# Example 29: label 0, features [4.7 3.2 1.6 0.2], name setosa
# Example 30: label 0, features [4.8 3.1 1.6 0.2], name setosa
# Example 31: label 0, features [5.4 3.4 1.5 0.4], name setosa
# Example 32: label 0, features [5.2 4.1 1.5 0.1], name setosa
# Example 33: label 0, features [5.5 4.2 1.4 0.2], name setosa
# Example 34: label 0, features [4.9 3.1 1.5 0.2], name setosa
# Example 35: label 0, features [5.  3.2 1.2 0.2], name setosa
# Example 36: label 0, features [5.5 3.5 1.3 0.2], name setosa
# Example 37: label 0, features [4.9 3.6 1.4 0.1], name setosa
# Example 38: label 0, features [4.4 3.  1.3 0.2], name setosa
# Example 39: label 0, features [5.1 3.4 1.5 0.2], name setosa
# Example 40: label 0, features [5.  3.5 1.3 0.3], name setosa
# Example 41: label 0, features [4.5 2.3 1.3 0.3], name setosa
# Example 42: label 0, features [4.4 3.2 1.3 0.2], name setosa
# Example 43: label 0, features [5.  3.5 1.6 0.6], name setosa
# Example 44: label 0, features [5.1 3.8 1.9 0.4], name setosa
# Example 45: label 0, features [4.8 3.  1.4 0.3], name setosa
# Example 46: label 0, features [5.1 3.8 1.6 0.2], name setosa
# Example 47: label 0, features [4.6 3.2 1.4 0.2], name setosa
# Example 48: label 0, features [5.3 3.7 1.5 0.2], name setosa
# Example 49: label 0, features [5.  3.3 1.4 0.2], name setosa
# Example 50: label 1, features [7.  3.2 4.7 1.4], name versicolor
# Example 51: label 1, features [6.4 3.2 4.5 1.5], name versicolor
# Example 52: label 1, features [6.9 3.1 4.9 1.5], name versicolor
# Example 53: label 1, features [5.5 2.3 4.  1.3], name versicolor
# Example 54: label 1, features [6.5 2.8 4.6 1.5], name versicolor
# Example 55: label 1, features [5.7 2.8 4.5 1.3], name versicolor
# Example 56: label 1, features [6.3 3.3 4.7 1.6], name versicolor
# Example 57: label 1, features [4.9 2.4 3.3 1. ], name versicolor
# Example 58: label 1, features [6.6 2.9 4.6 1.3], name versicolor
# Example 59: label 1, features [5.2 2.7 3.9 1.4], name versicolor
# Example 60: label 1, features [5.  2.  3.5 1. ], name versicolor
# Example 61: label 1, features [5.9 3.  4.2 1.5], name versicolor
# Example 62: label 1, features [6.  2.2 4.  1. ], name versicolor
# Example 63: label 1, features [6.1 2.9 4.7 1.4], name versicolor
# Example 64: label 1, features [5.6 2.9 3.6 1.3], name versicolor
# Example 65: label 1, features [6.7 3.1 4.4 1.4], name versicolor
# Example 66: label 1, features [5.6 3.  4.5 1.5], name versicolor
# Example 67: label 1, features [5.8 2.7 4.1 1. ], name versicolor
# Example 68: label 1, features [6.2 2.2 4.5 1.5], name versicolor
# Example 69: label 1, features [5.6 2.5 3.9 1.1], name versicolor
# Example 70: label 1, features [5.9 3.2 4.8 1.8], name versicolor
# Example 71: label 1, features [6.1 2.8 4.  1.3], name versicolor
# Example 72: label 1, features [6.3 2.5 4.9 1.5], name versicolor
# Example 73: label 1, features [6.1 2.8 4.7 1.2], name versicolor
# Example 74: label 1, features [6.4 2.9 4.3 1.3], name versicolor
# Example 75: label 1, features [6.6 3.  4.4 1.4], name versicolor
# Example 76: label 1, features [6.8 2.8 4.8 1.4], name versicolor
# Example 77: label 1, features [6.7 3.  5.  1.7], name versicolor
# Example 78: label 1, features [6.  2.9 4.5 1.5], name versicolor
# Example 79: label 1, features [5.7 2.6 3.5 1. ], name versicolor
# Example 80: label 1, features [5.5 2.4 3.8 1.1], name versicolor
# Example 81: label 1, features [5.5 2.4 3.7 1. ], name versicolor
# Example 82: label 1, features [5.8 2.7 3.9 1.2], name versicolor
# Example 83: label 1, features [6.  2.7 5.1 1.6], name versicolor
# Example 84: label 1, features [5.4 3.  4.5 1.5], name versicolor
# Example 85: label 1, features [6.  3.4 4.5 1.6], name versicolor
# Example 86: label 1, features [6.7 3.1 4.7 1.5], name versicolor
# Example 87: label 1, features [6.3 2.3 4.4 1.3], name versicolor
# Example 88: label 1, features [5.6 3.  4.1 1.3], name versicolor
# Example 89: label 1, features [5.5 2.5 4.  1.3], name versicolor
# Example 90: label 1, features [5.5 2.6 4.4 1.2], name versicolor
# Example 91: label 1, features [6.1 3.  4.6 1.4], name versicolor
# Example 92: label 1, features [5.8 2.6 4.  1.2], name versicolor
# Example 93: label 1, features [5.  2.3 3.3 1. ], name versicolor
# Example 94: label 1, features [5.6 2.7 4.2 1.3], name versicolor
# Example 95: label 1, features [5.7 3.  4.2 1.2], name versicolor
# Example 96: label 1, features [5.7 2.9 4.2 1.3], name versicolor
# Example 97: label 1, features [6.2 2.9 4.3 1.3], name versicolor
# Example 98: label 1, features [5.1 2.5 3.  1.1], name versicolor
# Example 99: label 1, features [5.7 2.8 4.1 1.3], name versicolor
# Example 100: label 2, features [6.3 3.3 6.  2.5], name virginica
# Example 101: label 2, features [5.8 2.7 5.1 1.9], name virginica
# Example 102: label 2, features [7.1 3.  5.9 2.1], name virginica
# Example 103: label 2, features [6.3 2.9 5.6 1.8], name virginica
# Example 104: label 2, features [6.5 3.  5.8 2.2], name virginica
# Example 105: label 2, features [7.6 3.  6.6 2.1], name virginica
# Example 106: label 2, features [4.9 2.5 4.5 1.7], name virginica
# Example 107: label 2, features [7.3 2.9 6.3 1.8], name virginica
# Example 108: label 2, features [6.7 2.5 5.8 1.8], name virginica
# Example 109: label 2, features [7.2 3.6 6.1 2.5], name virginica
# Example 110: label 2, features [6.5 3.2 5.1 2. ], name virginica
# Example 111: label 2, features [6.4 2.7 5.3 1.9], name virginica
# Example 112: label 2, features [6.8 3.  5.5 2.1], name virginica
# Example 113: label 2, features [5.7 2.5 5.  2. ], name virginica
# Example 114: label 2, features [5.8 2.8 5.1 2.4], name virginica
# Example 115: label 2, features [6.4 3.2 5.3 2.3], name virginica
# Example 116: label 2, features [6.5 3.  5.5 1.8], name virginica
# Example 117: label 2, features [7.7 3.8 6.7 2.2], name virginica
# Example 118: label 2, features [7.7 2.6 6.9 2.3], name virginica
# Example 119: label 2, features [6.  2.2 5.  1.5], name virginica
# Example 120: label 2, features [6.9 3.2 5.7 2.3], name virginica
# Example 121: label 2, features [5.6 2.8 4.9 2. ], name virginica
# Example 122: label 2, features [7.7 2.8 6.7 2. ], name virginica
# Example 123: label 2, features [6.3 2.7 4.9 1.8], name virginica
# Example 124: label 2, features [6.7 3.3 5.7 2.1], name virginica
# Example 125: label 2, features [7.2 3.2 6.  1.8], name virginica
# Example 126: label 2, features [6.2 2.8 4.8 1.8], name virginica
# Example 127: label 2, features [6.1 3.  4.9 1.8], name virginica
# Example 128: label 2, features [6.4 2.8 5.6 2.1], name virginica
# Example 129: label 2, features [7.2 3.  5.8 1.6], name virginica
# Example 130: label 2, features [7.4 2.8 6.1 1.9], name virginica
# Example 131: label 2, features [7.9 3.8 6.4 2. ], name virginica
# Example 132: label 2, features [6.4 2.8 5.6 2.2], name virginica
# Example 133: label 2, features [6.3 2.8 5.1 1.5], name virginica
# Example 134: label 2, features [6.1 2.6 5.6 1.4], name virginica
# Example 135: label 2, features [7.7 3.  6.1 2.3], name virginica
# Example 136: label 2, features [6.3 3.4 5.6 2.4], name virginica
# Example 137: label 2, features [6.4 3.1 5.5 1.8], name virginica
# Example 138: label 2, features [6.  3.  4.8 1.8], name virginica
# Example 139: label 2, features [6.9 3.1 5.4 2.1], name virginica
# Example 140: label 2, features [6.7 3.1 5.6 2.4], name virginica
# Example 141: label 2, features [6.9 3.1 5.1 2.3], name virginica
# Example 142: label 2, features [5.8 2.7 5.1 1.9], name virginica
# Example 143: label 2, features [6.8 3.2 5.9 2.3], name virginica
# Example 144: label 2, features [6.7 3.3 5.7 2.5], name virginica
# Example 145: label 2, features [6.7 3.  5.2 2.3], name virginica
# Example 146: label 2, features [6.3 2.5 5.  1.9], name virginica
# Example 147: label 2, features [6.5 3.  5.2 2. ], name virginica
# Example 148: label 2, features [6.2 3.4 5.4 2.3], name virginica
# Example 149: label 2, features [5.9 3.  5.1 1.8], name virginica

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
sepal = iris.data[:,0:2]
kind = iris.target

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.plot(sepal[kind==0][:,0],sepal[kind==0][:,1],'ro',label='Setosa')
plt.plot(sepal[kind==1][:,0],sepal[kind==1][:,1],'bo',label='Versicolor')
plt.plot(sepal[kind==2][:,0],sepal[kind==2][:,1],'yo',label='Virginica')

plt.legend()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data,iris.target,test_size=0.2,random_state=4)
print(X_train.shape)
print(X_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)
y_df = pd.DataFrame({'y_test':y_test,'y_pred':y_pred})


scores = metrics.accuracy_score(y_test,y_pred)
scores
# Out:
# 0.9666666666666667

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X,y)

classes = {0:'setosa',1:'versicolor',2:'virginica'}

x_news = [[3,4,5,2],[5,4,2,2]]
y_new_pred = knn.predict(x_news)

classes[y_new_pred[0]]
classes[y_new_pred[1]]
# Out:
# 'setosa'

# %%
import mod_sql #이전에 만든 sql문 구동 모듈
import pandas as pd
import matplotlib.pyplot as plt
import pymysql

# %%
# db = mod_sql.Databse()
# sql = 'SELECT * FROM sales'
# result = db.executeAll(sql)
# dt = pd.DataFrame(result)
# dt
# #sql로 넣은 자료를 파이썬에 호출

_db = mod_sql.Databse()
# pymysql.connect(
#       user = 'ubion',
#       passwd = '1234',
#       host = 'darkpreist.iptime.org',
#       db='ubion',
#       port = 3306  
# )

# %%
# cursor = _db.cursor(pymysql.cursors.DictCursor)

# %%
sql_s = '''
        SELECT Country, `Units Sold`, `Unit Cost`,`Units Sold`*`Unit Cost` as `Total Cost1`,`Total Cost` FROM sales 
        GROUP BY Country
        '''
# print(1)
# cursor.execute(sql_s)
# print(2)
# result = cursor.fetchall()
# print(3)
# df = pd.DataFrame(result)
# df
result = _db.executeAll(sql_s)
df = pd.DataFrame(result)
df
# Out:
#                               Country  Units Sold  Unit Cost  Total Cost1  \
# 0                                Chad        4484     524.96   2353920.64
# 1                              Latvia        1075      31.79     34174.25
# 2                            Pakistan        6515      90.93    592408.95
# 3    Democratic Republic of the Congo        7683     502.54   3861014.82
# 4                      Czech Republic        3491      31.79    110978.89
# ..                                ...         ...        ...          ...
# 180                            Jordan        6418     502.54   3225301.72
# 181                     Guinea-Bissau        5245      97.44    511072.80
# 182                           Bahrain        4597      35.84    164756.48
# 183                     Cote d'Ivoire         855     159.42    136304.10
# 184                          Malaysia        8457      35.84    303098.88
#
#      Total Cost
# 0    2353920.64
# 1      34174.25
# 2     592408.95
# ...

# %%
sql_s_2 = '''
          SELECT * FROM sales GROUP BY Country
          '''
# cursor.execute(sql_s_2)
# result_s_2 = cursor.fetchall()
# df_s_2 = pd.DataFrame(result_s_2)
# df_s_2
result_s_2 = _db.executeAll(sql_s_2)
df_s_2 = pd.DataFrame(result_s_2)
df_s_2
# Out:
#                            Region                           Country  \
# 0              Sub-Saharan Africa                              Chad
# 1                          Europe                            Latvia
# 2    Middle East and North Africa                          Pakistan
# 3              Sub-Saharan Africa  Democratic Republic of the Congo
# 4                          Europe                    Czech Republic
# ..                            ...                               ...
# 180  Middle East and North Africa                            Jordan
# 181            Sub-Saharan Africa                     Guinea-Bissau
# 182  Middle East and North Africa                           Bahrain
# 183            Sub-Saharan Africa                     Cote d'Ivoire
# 184                          Asia                          Malaysia
#
#            Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0    Office Supplies        Online              L   1/27/2011  292494523
# ...

# %%
sql_s_3 = '''
	SELECT * FROM sales GROUP BY Country
	'''

# result_2 = db.executeAll(sql_2)
# dt_2 = pd.DataFrame(result_2)
# print(1)


# sql_3 = '''
# 	SELECT Country, SUM(`Units Sold`) FROM sales GROUP BY Country ORDER BY `Units Sold`
# 	'''
# #여기서 내림차순 변경 시 DESC를 쿼리문 마지막에 추가한다.
# #또는 
# 	# '''
# 	# SELECT Country, SUM(`Units Sold`) AS 'units sold' FROM sales GROUP BY Country `units sold`
# 	# '''
# # 이때, sql에서는 
# # column의 값에 공백이 있으므로 이 경우 `(~기호)를 '(" 기호) 대신 사용한다.
# print(2)
# result_3 = db.executeAll(sql_3)

# print(3)
# dt_3 = pd.DataFrame(result_3)

# dt_3
result_3 = _db.executeAll(sql_s_3)
df_s_3 = pd.DataFrame(result_3)
df_s_3
# Out:
#                            Region                           Country  \
# 0              Sub-Saharan Africa                              Chad
# 1                          Europe                            Latvia
# 2    Middle East and North Africa                          Pakistan
# 3              Sub-Saharan Africa  Democratic Republic of the Congo
# 4                          Europe                    Czech Republic
# ..                            ...                               ...
# 180  Middle East and North Africa                            Jordan
# 181            Sub-Saharan Africa                     Guinea-Bissau
# 182  Middle East and North Africa                           Bahrain
# 183            Sub-Saharan Africa                     Cote d'Ivoire
# 184                          Asia                          Malaysia
#
#            Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0    Office Supplies        Online              L   1/27/2011  292494523
# ...

# %% [markdown]
# 1. 그룹화 국가
# 2. 출력 -> country, country 갯수를 구하는 dataframe을 만들어라
# 3. country 갯수를 기준으로 내림차순 정렬

# %%
# #1번
# db_1 = mod_sql.Databse()
sql_q = '''SELECT Country, COUNT('Country') AS cnt
            FROM sales
            GROUP BY Country
            ORDER BY cnt ASC
            '''

# result_q = db_1.executeAll(sql_q)
# dt_q = pd.DataFrame(result_q)
# dt_q
result_q = _db.executeAll(sql_q)
df_q = pd.DataFrame(result_q)
df_q
# Out:
#             Country  cnt
# 0              Mali   35
# 1       Saint Lucia   39
# 2        Tajikistan   40
# 3         Greenland   41
# 4          Slovakia   42
# ..              ...  ...
# 180     Seychelles    70
# 181         Croatia   70
# 182        Moldova    71
# 183       Lithuania   72
# 184  United Kingdom   72
#
# [185 rows x 2 columns]

# %%
sql_avg = '''
            SELECT Country, SUM(`Units Sold`) as Total_Sold, AVG(`Units Sold`) as Avg_Sold
            FROM sales
            GROUP BY Country
            ORDER BY Avg_Sold DESC
            '''
# print(1)
# result_avg = db.executeAll(sql_avg)
# print(2)
# df_avg = pd.DataFrame(result_avg)
# print(3)
# df_avg
result_avg = _db.executeAll(sql_avg)
df_avg = pd.DataFrame(result_avg)
df_avg
# Out:
#                Country Total_Sold   Avg_Sold
# 0            Nicaragua     260645  6061.5116
# 1               Taiwan     380647  5947.6094
# 2             Slovakia     246683  5873.4048
# 3              Grenada     355886  5834.1967
# 4            Greenland     236829  5776.3171
# ..                 ...        ...        ...
# 180         East Timor     201455  4286.2766
# 181  Equatorial Guinea     192706  4282.3556
# 182     United Kingdom     294152  4085.4444
# 183               Togo     227930  3998.7719
# 184            Lesotho     214294  3694.7241
#
# [185 rows x 3 columns]
